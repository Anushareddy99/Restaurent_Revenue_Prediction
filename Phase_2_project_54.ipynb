# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import math

train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

# %%
actual_value=([2,3,4,5,6,7,9])
predicted_value=([1,2,3,4,5,8,3])

# %%
# root mean square error(rmse)
def rmse(actual_value,predicted_value):
  actual_value=np.array(actual_value)
  predicted_value=np.array(predicted_value)
  return np.sqrt(((np.subtract(actual_value,predicted_value)**2).mean()))
print(rmse(actual_value,predicted_value))
# Out:
# 2.449489742783178

# %%
from sklearn.metrics import mean_squared_error
import math
mse=mean_squared_error(actual_value,predicted_value)
print(math.sqrt(mse)) # RMSE
# Out:
# 2.449489742783178

# %% [markdown]
# Data-set level and output-variable analysis
# **bold text**

# %%
train.shape
# Out:
# (137, 43)

# %%
test.shape
# Out:
# (100000, 42)

# %%
train.describe()
# Out:
#                Id          P1          P2          P3          P4          P5  \
# count  137.000000  137.000000  137.000000  137.000000  137.000000  137.000000
# mean    68.000000    4.014599    4.408759    4.317518    4.372263    2.007299
# std     39.692569    2.910391    1.514900    1.032337    1.016462    1.209620
# min      0.000000    1.000000    1.000000    0.000000    3.000000    1.000000
# 25%     34.000000    2.000000    4.000000    4.000000    4.000000    1.000000
# 50%     68.000000    3.000000    5.000000    4.000000    4.000000    2.000000
# 75%    102.000000    4.000000    5.000000    5.000000    5.000000    2.000000
# max    136.000000   12.000000    7.500000    7.500000    7.500000    8.000000
#
#                P6          P7          P8          P9  ...         P29  \
# count  137.000000  137.000000  137.000000  137.000000  ...  137.000000
# mean     3.357664    5.423358    5.153285    5.445255  ...    3.135036
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 137 entries, 0 to 136
# Data columns (total 43 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Id          137 non-null    int64
#  1   Open Date   137 non-null    object
#  2   City        137 non-null    object
#  3   City Group  137 non-null    object
#  4   Type        137 non-null    object
#  5   P1          137 non-null    int64
#  6   P2          137 non-null    float64
#  7   P3          137 non-null    float64
#  8   P4          137 non-null    float64
#  9   P5          137 non-null    int64
#  10  P6          137 non-null    int64
#  11  P7          137 non-null    int64
#  12  P8          137 non-null    int64
#  13  P9          137 non-null    int64
#  14  P10         137 non-null    int64
#  15  P11         137 non-null    int64
#  16  P12         137 non-null    int64
#  17  P13         137 non-null    float64
#  18  P14         137 non-null    int64
# ...

# %%
train.head(5)
# Out:
#    Id   Open Date        City  City Group Type  P1   P2   P3   P4  P5  ...  \
# 0   0  07/17/1999    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2  ...
# 1   1  02/14/2008      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1  ...
# 2   2  03/09/2013  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2  ...
# 3   3  02/02/2012       Tokat       Other   IL   6  4.5  6.0  6.0   4  ...
# 4   4  05/09/2009   Gaziantep       Other   IL   3  4.0  3.0  4.0   2  ...
#
#    P29  P30  P31  P32  P33  P34  P35  P36  P37    revenue
# 0  3.0    5    3    4    5    5    4    3    4  5653753.0
# 1  3.0    0    0    0    0    0    0    0    0  6923131.0
# 2  3.0    0    0    0    0    0    0    0    0  2055379.0
# 3  7.5   25   12   10    6   18   12   12    6  2675511.0
# 4  3.0    5    1    3    2    3    4    3    3  4316715.0
#
# [5 rows x 43 columns]

# %%
train.isna().sum()#No null values
# Out:
# Id            0
# Open Date     0
# City          0
# City Group    0
# Type          0
# P1            0
# P2            0
# P3            0
# P4            0
# P5            0
# P6            0
# P7            0
# P8            0
# P9            0
# P10           0
# P11           0
# P12           0
# P13           0
# P14           0
# P15           0
# P16           0
# P17           0
# P18           0
# P19           0
# P20           0
# P21           0
# P22           0
# P23           0
# P24           0
# P25           0
# P26           0
# P27           0
# P28           0
# P29           0
# P30           0
# P31           0
# P32           0
# P33           0
# P34           0
# P35           0
# P36           0
# P37           0
# revenue       0
# dtype: int64

# %%
train.City.value_counts()
# Out:
# İstanbul          50
# Ankara            19
# İzmir              9
# Bursa              5
# Samsun             5
# Sakarya            4
# Antalya            4
# Kayseri            3
# Eskişehir          3
# Adana              3
# Diyarbakır         3
# Tekirdağ           3
# Muğla              2
# Trabzon            2
# Aydın              2
# Konya              2
# Karabük            1
# Isparta            1
# Bolu               1
# Kütahya            1
# Amasya             1
# Balıkesir          1
# Denizli            1
# Kocaeli            1
# Kırklareli         1
# Edirne             1
# Uşak               1
# Kastamonu          1
# Tokat              1
# Şanlıurfa          1
# Elazığ             1
# Gaziantep          1
# Afyonkarahisar     1
# Osmaniye           1
# Name: City, dtype: int64

# %%
train['City Group'].value_counts()
# Out:
# Big Cities    78
# Other         59
# Name: City Group, dtype: int64

# %%
train.Type.value_counts()
# Out:
# FC    76
# IL    60
# DT     1
# Name: Type, dtype: int64

# %%
train.columns
# Out:
# Index(['Id', 'Open Date', 'City', 'City Group', 'Type', 'P1', 'P2', 'P3', 'P4',
#        'P5', 'P6', 'P7', 'P8', 'P9', 'P10', 'P11', 'P12', 'P13', 'P14', 'P15',
#        'P16', 'P17', 'P18', 'P19', 'P20', 'P21', 'P22', 'P23', 'P24', 'P25',
#        'P26', 'P27', 'P28', 'P29', 'P30', 'P31', 'P32', 'P33', 'P34', 'P35',
#        'P36', 'P37', 'revenue'],
#       dtype='object')

# %%
from datetime import datetime
#open date and end date difference
def get_age(open_date):
  open_date = datetime.strptime(open_date,"%m/%d/%Y")
  difference = datetime.strptime("12/31/2015","%m/%d/%Y") - open_date
  return difference.days

# %%
train['Year'] = pd.DatetimeIndex(train['Open Date']).year#year
train['Month'] = pd.DatetimeIndex(train['Open Date']).month#month
train['Day_of_week']=pd.DatetimeIndex(train['Open Date']).dayofweek# dayofweek
train['Weekend']=train.apply(lambda row: 1 if row['Day_of_week'] >= 5 else 0,axis=1)#weekend
train['Age_of_Restaurent']=train.apply(lambda row: get_age(row["Open Date"]),axis = 1)#age of restaurent 

# drop open date
train=train.drop("Open Date",axis = 1)
train
#here we seperate the year,month,day for the open date column
# Out:
#       Id        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  P34  \
# 0      0    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...    5
# 1      1      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...    0
# 2      2  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3  ...    0
# 3      3       Tokat       Other   IL   6  4.5  6.0  6.0   4   4  ...   18
# 4      4   Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2  ...    3
# ..   ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...  ...
# 132  132     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2  ...    0
# 133  133       İzmir  Big Cities   FC   4  5.0  4.0  4.0   2   3  ...    0
# 134  134     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3  ...    0
# 135  135    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...    0
# 136  136    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...    0
#
#      P35  P36  P37    revenue  Year  Month  Day_of_week  Weekend  \
# ...

# %% [markdown]
# **Revenue- univariate**

# %%
sns.distplot(train.revenue)#pdf plot
plt.title("pdf plot for revenue in train data")
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'pdf plot for revenue in train data')

# %% [markdown]
# there are some outlier in revenue few restaurents are showing high revenue.it is overfitting data and right skewed pdf(probability density function) plot

# %%
sns.boxplot(train.revenue)#Boxplot
plt.title("boxplot for revenue")
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'boxplot for revenue')

# %% [markdown]
# removing outliers for the revenue data in index

# %%
index_values = train[train["revenue"]>8000000].index
train = train.drop(index_values)
train
# Out:
#       Id        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  P34  \
# 0      0    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...    5
# 1      1      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...    0
# 2      2  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3  ...    0
# 3      3       Tokat       Other   IL   6  4.5  6.0  6.0   4   4  ...   18
# 4      4   Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2  ...    3
# ..   ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...  ...
# 131  131      Ankara  Big Cities   FC   3  4.0  4.0  5.0   3   4  ...    0
# 132  132     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2  ...    0
# 134  134     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3  ...    0
# 135  135    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...    0
# 136  136    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...    0
#
#      P35  P36  P37    revenue  Year  Month  Day_of_week  Weekend  \
# ...

# %%
sns.distplot(train.revenue)
plt.grid
plt.title("after remove outliers in pdf plot")
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'after remove outliers in pdf plot')

# %%
sns.histplot(train.Year,bins=25)
plt.title("year")
# Out:
# Text(0.5, 1.0, 'year')

# %% [markdown]
# 2011 has more opening
# 1996 has less opening

# %%
sns.histplot(train.Month,bins=25)
plt.title("month")
# Out:
# Text(0.5, 1.0, 'month')

# %% [markdown]
# August and december has more restaurent opening
# April has less restaurent opening

# %%
sns.histplot(train.Day_of_week,bins=25)
plt.title("dayofweek")
# Out:
# Text(0.5, 1.0, 'dayofweek')

# %%
sns.histplot(train.Age_of_Restaurent,bins=25)
plt.title("Age of Restaurent in days")
# Out:
# Text(0.5, 1.0, 'Age of Restaurent in days')

# %% [markdown]
# 1 day has more opening

# %% [markdown]
# **Revenue Analysis:**

# %% [markdown]
# Bi variate analysis

# %% [markdown]
# Revenue vs City

# %%
temp_df = train[["City","revenue"]].groupby("City").agg("sum")
#separte by city and added revenue
temp_df
# Out:
#                     revenue
# City
# Adana            14684833.0
# Afyonkarahisar    4952497.0
# Amasya            2954086.0
# Ankara           62232711.0
# Antalya          13925793.0
# Aydın             6859597.0
# Balıkesir         4758476.0
# Bolu              4263629.0
# Bursa            20461475.0
# Denizli           2344689.0
# Diyarbakır       11206054.0
# Edirne            5444227.0
# Elazığ            5525735.0
# Eskişehir        11873860.0
# Gaziantep         4316715.0
# Isparta           4015749.0
# Karabük           3807496.0
# Kastamonu         3273041.0
# Kayseri          13702727.0
# Kocaeli           3745135.0
# Konya             5334513.0
# Kütahya           2993069.0
# Kırklareli        1619683.0
# Muğla             8222258.0
# Osmaniye          3376145.0
# Sakarya          13315413.0
# Samsun           16239348.0
# Tekirdağ          9937412.0
# Tokat             2675511.0
# Trabzon          10568201.0
# Uşak              1763231.0
# İstanbul        193668731.0
# ...

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(temp_df.index,temp_df.revenue)# barplot to show city revenue
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
plt.title("city and revenue")
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Istanbul has high revenue
# Amasya,Denizli,Mugla,kirklareli,Usak,Sanliurfa has less revenue

# %%
temp_df = train[["City Group","revenue"]].groupby("City Group").agg("sum")

temp_df
# Out:
#                 revenue
# City Group
# Big Cities  285332227.0
# Other       221422522.0

# %%
plt.figure(figsize=(8,5))
sns.barplot(temp_df.index,temp_df.revenue)
plt.title('city group and revenue')
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# big cities have more revenue
# other have less revenue

# %%
temp_df = train[["Type","revenue"]].groupby("Type").agg("sum")
temp_df
# Out:
#           revenue
# Type
# DT      3810007.0
# FC    275081296.0
# IL    227863446.0

# %%
plt.figure(figsize=(8,5))
sns.barplot(temp_df.index,temp_df.revenue)
plt.title('type and revenue')
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# food court(fc) have more revenue
# drive thru(dt) have less revenue

# %% [markdown]
# Year vs Revenue

# %%
temp_df = train[["Year","revenue"]].groupby("Year").agg("sum")
temp_df
# Out:
#           revenue
# Year
# 1996    3903884.0
# 1997    4286645.0
# 1998   17007620.0
# 1999   15740895.0
# 2000    7495092.0
# 2002    9982044.0
# 2004   10447304.0
# 2005    9895410.0
# 2006   20165047.0
# 2007   25902981.0
# 2008   59646782.0
# 2009   57321706.0
# 2010   65758164.0
# 2011  103696974.0
# 2012   60186870.0
# 2013   30387442.0
# 2014    4929889.0

# %%
plt.figure(figsize=(12,8))
sns.barplot(temp_df.index,temp_df.revenue)
plt.title("year vs revenue")
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# 2011 has more revenue
# 1996,1997,2014 has less revenue

# %% [markdown]
# Month vs revenue

# %%
temp_df= train[["Month","revenue"]].groupby("Month").agg("sum")
temp_df
# Out:
#           revenue
# Month
# 1      45212427.0
# 2      46080202.0
# 3      34770525.0
# 4      14999802.0
# 5      36578002.0
# 6      33985929.0
# 7      27668769.0
# 8      66011346.0
# 9      40742978.0
# 10     52740746.0
# 11     48443273.0
# 12     59520750.0

# %%
plt.figure(figsize=(12,8))
sns.barplot(temp_df.index,temp_df.revenue)
plt.title("month and revenue")
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# october,december,january,august have more restaurent revenue
# april has less revenue

# %% [markdown]
# day vs revenue

# %%
temp_df = train[["Day_of_week","revenue"]].groupby("Day_of_week").agg("sum")
temp_df
# Out:
#                  revenue
# Day_of_week
# 0             64039248.0
# 1             84339271.0
# 2             89310688.0
# 3             49099670.0
# 4             91502799.0
# 5            101727913.0
# 6             26735160.0

# %%
plt.figure(figsize=(13,8))
sns.barplot(temp_df.index,temp_df.revenue)

plt.title('dayofweek and revenue')
plt.legend()
plt.show()
# Out:
# C:\Users\madhu\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# most restaurant started on 1 day then after for 7,9,21,25 days revenue

# %%
train
# Out:
#       Id        City  City Group Type  P1   P2   P3   P4  P5  P6  ...  P34  \
# 0      0    İstanbul  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...    5
# 1      1      Ankara  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...    0
# 2      2  Diyarbakır       Other   IL   2  4.0  2.0  5.0   2   3  ...    0
# 3      3       Tokat       Other   IL   6  4.5  6.0  6.0   4   4  ...   18
# 4      4   Gaziantep       Other   IL   3  4.0  3.0  4.0   2   2  ...    3
# ..   ...         ...         ...  ...  ..  ...  ...  ...  ..  ..  ...  ...
# 131  131      Ankara  Big Cities   FC   3  4.0  4.0  5.0   3   4  ...    0
# 132  132     Trabzon       Other   FC   2  3.0  3.0  5.0   4   2  ...    0
# 134  134     Kayseri       Other   FC   3  4.0  4.0  4.0   2   3  ...    0
# 135  135    İstanbul  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...    0
# 136  136    İstanbul  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...    0
#
#      P35  P36  P37    revenue  Year  Month  Day_of_week  Weekend  \
# ...

# %% [markdown]
# **correlation**

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(corrmat, vmax=1, square=True);

# %% [markdown]
# **Feature Transformation**

# %% [markdown]
# label encoder transfrom categorical data into numerical data

# %%
from sklearn.preprocessing import LabelEncoder
city_label_encoder = LabelEncoder()
city_label_encoder = city_label_encoder.fit(train['City'])
train['City'] = city_label_encoder.transform(train['City'])#label encoder for city
train
# Out:
#       Id  City  City Group Type  P1   P2   P3   P4  P5  P6  ...  P34  P35  \
# 0      0    31  Big Cities   IL   4  5.0  4.0  4.0   2   2  ...    5    4
# 1      1     3  Big Cities   FC   4  5.0  4.0  4.0   1   2  ...    0    0
# 2      2    10       Other   IL   2  4.0  2.0  5.0   2   3  ...    0    0
# 3      3    28       Other   IL   6  4.5  6.0  6.0   4   4  ...   18   12
# 4      4    14       Other   IL   3  4.0  3.0  4.0   2   2  ...    3    4
# ..   ...   ...         ...  ...  ..  ...  ...  ...  ..  ..  ...  ...  ...
# 131  131     3  Big Cities   FC   3  4.0  4.0  5.0   3   4  ...    0    0
# 132  132    29       Other   FC   2  3.0  3.0  5.0   4   2  ...    0    0
# 134  134    18       Other   FC   3  4.0  4.0  4.0   2   3  ...    0    0
# 135  135    31  Big Cities   FC   4  5.0  4.0  5.0   2   2  ...    0    0
# 136  136    31  Big Cities   FC   4  5.0  3.0  5.0   2   2  ...    0    0
#
#      P36  P37    revenue  Year  Month  Day_of_week  Weekend  Age_of_Restaurent
# ...

# %% [markdown]
# Here citis data into numerical data

# %%
cg_label_encoder = LabelEncoder()
train['City Group'] = cg_label_encoder.fit_transform(train['City Group'])#label encoder for city group

# %% [markdown]
# Here city group data into numerical data(big cities=0,other=1)

# %%
type_label_encoder = LabelEncoder()
train["Type"]=type_label_encoder.fit_transform(train['Type'])#label encoder for type

# %% [markdown]
# Here type data into numerical data(DT-0,FC-1,IL-2)

# %%
train.set_index("Id")
# Out:
#      City  City Group  Type  P1   P2   P3   P4  P5  P6  P7  ...  P34  P35  \
# Id                                                          ...
# 0      31           0     2   4  5.0  4.0  4.0   2   2   5  ...    5    4
# 1       3           0     1   4  5.0  4.0  4.0   1   2   5  ...    0    0
# 2      10           1     2   2  4.0  2.0  5.0   2   3   5  ...    0    0
# 3      28           1     2   6  4.5  6.0  6.0   4   4  10  ...   18   12
# 4      14           1     2   3  4.0  3.0  4.0   2   2   5  ...    3    4
# ..    ...         ...   ...  ..  ...  ...  ...  ..  ..  ..  ...  ...  ...
# 131     3           0     1   3  4.0  4.0  5.0   3   4   5  ...    0    0
# 132    29           1     1   2  3.0  3.0  5.0   4   2   4  ...    0    0
# 134    18           1     1   3  4.0  4.0  4.0   2   3   5  ...    0    0
# 135    31           0     1   4  5.0  4.0  5.0   2   2   5  ...    0    0
# 136    31           0     1   4  5.0  3.0  5.0   2   2   5  ...    0    0
#
# ...

# %% [markdown]
# Final output label encoder

# %%
#one-hot encoder
ohe_City_Group=pd.get_dummies(train['City Group'])
ohe_City_Group
# Out:
#      0  1
# 0    1  0
# 1    1  0
# 2    0  1
# 3    0  1
# 4    0  1
# ..  .. ..
# 131  1  0
# 132  0  1
# 134  0  1
# 135  1  0
# 136  1  0
#
# [128 rows x 2 columns]

# %%
ohe_Type=pd.get_dummies(train['Type'])
ohe_Type
# Out:
#      0  1  2
# 0    0  0  1
# 1    0  1  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 131  0  1  0
# 132  0  1  0
# 134  0  1  0
# 135  0  1  0
# 136  0  1  0
#
# [128 rows x 3 columns]

# %%
# from sklearn.preprocessing import Normalizer
# standardiser = Normalizer()
# standardiser.fit(train_x)
# train_x = standardiser.transform(train_x)
# train_x
